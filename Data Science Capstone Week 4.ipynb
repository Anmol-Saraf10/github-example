# %% [markdown]
# Installing BeautifulSoup and lxml

# %%
import sys
# !conda install --yes --prefix {sys.prefix} beautifulsoup4
# !conda install --yes --prefix {sys.prefix} lxml
# !conda install -c conda-forge geopy --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         156 KB
#
# The following packages will be UPDATED:
#
#     certifi:         2019.6.16-py36_1     conda-forge --> 2019.6.16-py36_1
#     openssl:         1.1.1c-h516909a_0    conda-forge --> 1.1.1c-h7b6447c_1
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2019.6.16-hecc5488_0 conda-forge --> 2019.5.15-1
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 156 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1       --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1  --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1 --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Importing all the necessary packages for data manipulation

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Getting the data from Wikipedia and removing unnecessary columns

# %%
source= requests.get("https://en.wikipedia.org/wiki/Planning_Areas_of_Singapore").text
soup=BeautifulSoup(source, 'lxml')
data_table=soup.find('table', class_="wikitable sortable")
table_rows = data_table.find_all('tr')
l = []
for tr in table_rows:
    td = tr.find_all('td')
    #row = [tr.text for tr in td]
    #l.append(row)
    row = [tr.text.strip() for tr in td if tr]
    if row:
        l.append(row)
raw_table=pd.DataFrame(l, columns=["Area_Name","Malay","Chinese","Pinyin","Tamil","Region","Area","Population","Density"])
#Dropping columns that are not needed 
raw_table.drop(columns=['Malay',"Chinese","Pinyin","Tamil","Density"], inplace=True)
raw_table.head()
# Out:
#      Area_Name      Region   Area Population
# 0   Ang Mo Kio  North-East  13.94    165,710
# 1        Bedok        East  21.69    281,300
# 2       Bishan     Central   7.62     88,490
# 3     Boon Lay        West   8.23         30
# 4  Bukit Batok        West  11.13    144,410

# %% [markdown]
# Retrieving the coordinates for all the areas in Singapore

# %%
#retrieving the coordinates
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="SG_Explorer")
raw_table['Area_lat']=raw_table['Area_Name'].apply(geolocator.geocode).apply(lambda x: (x.latitude))
raw_table['Area_lon']=raw_table['Area_Name'].apply(geolocator.geocode).apply(lambda x: (x.longitude))
raw_table.head(54)
# Out:
#                   Area_Name      Region   Area Population   Area_lat  \
# 0                Ang Mo Kio  North-East  13.94    165,710   1.369842
# 1                     Bedok        East  21.69    281,300   1.323976
# 2                    Bishan     Central   7.62     88,490   1.351452
# 3                  Boon Lay        West   8.23         30   1.345640
# 4               Bukit Batok        West  11.13    144,410   1.349057
# 5               Bukit Merah     Central  14.34    151,870   4.559288
# 6             Bukit Panjang        West   8.99    140,820   1.377921
# 7               Bukit Timah     Central  17.53     77,280   1.354690
# 8   Central Water Catchment       North  37.15          * -33.559364
# 9                    Changi        East  40.61      2,080  36.839435
# 10               Changi Bay        East    1.7          *   1.316850
# 11            Choa Chu Kang        West   6.11    187,510   1.389260
# 12                 Clementi        West   9.49     93,000   1.314026
# 13            Downtown Core     Central   4.34      2,510  53.541427
# 14                  Geylang     Central   9.64    111,610   1.318186
# 15                  Hougang  North-East  13.93    223,010   1.373360
# 16              Jurong East        West  17.83     81,180   1.333115
# 17              Jurong West        West  14.69    266,720   1.339636
# 18                  Kallang     Central   9.17    101,420   1.310759
# 19             Lim Chu Kang       North   17.3        110   1.434217
# 20                   Mandai       North  11.77      2,090  -5.001769
# 21              Marina East     Central   1.82          *   1.288624
# 22             Marina South     Central   1.62          *   1.276998
# 23            Marine Parade     Central   6.12     47,250   1.302689
# 24                   Museum     Central   0.83        420  42.606151
# 25                   Newton     Central   2.07      7,640  42.337041
# 26    North-Eastern Islands  North-East  42.88         50  23.859453
# 27                   Novena     Central   8.98     48,950   1.320084
# 28                  Orchard     Central   0.96        990  37.394172
# 29                   Outram     Central   1.37     20,030  44.953744
# 30                Pasir Ris        East  15.02    146,920   1.375989
# 31               Paya Lebar        East  11.69         40   1.353899
# 32                  Pioneer        West   12.1         90  38.431855
# 33                  Punggol  North-East   9.34    161,570   1.398033
# 34               Queenstown     Central  20.43     97,870 -45.031720
# 35             River Valley     Central   1.48      9,930  48.020239
# 36                   Rochor     Central   1.62     13,450   1.303984
# 37                  Seletar  North-East  10.25        250   1.409849
# 38                Sembawang       North  12.34     87,380   1.126417
# 39                 Sengkang  North-East  10.59    240,640   1.390949
# 40                Serangoon  North-East   10.1    117,310   1.363236
# 41                  Simpang       North   5.13          *  -6.683763
# 42          Singapore River     Central   0.96      2,980   1.289178
# 43         Southern Islands     Central   6.07      1,800   1.271089
# 44             Straits View     Central   0.77          *   1.278333
# 45             Sungei Kadut       North  15.99        780   1.414997
# 46                 Tampines        East  20.89    257,110   1.354653
# 47                  Tanglin     Central   7.63     20,960   1.306044
# 48                   Tengah        West    7.4         10  -5.150000
# 49                Toa Payoh     Central   8.17    120,480   1.335391
# 50                     Tuas        West  30.04         70   1.329372
# 51          Western Islands        West  39.47         10  45.047353
# 52  Western Water Catchment        West  69.46        720   1.366452
# 53                Woodlands       North  13.59    252,530  54.355847
#
#       Area_lon
# 0   103.846609
# 1   103.930216
# 2   103.848250
# 3   103.711802
# 4   103.749591
# 5   101.025582
# 6   103.771866
# 7   103.776372
# 8   118.150469
# 9   119.401326
# 10  104.020649
# 11  103.743728
# 12  103.762410
# 13 -113.500434
# 14  103.887056
# 15  103.886091
# 16  103.742297
# 17  103.707339
# 18  103.866262
# 19  103.714987
# 20  -45.611204
# 21  103.869827
# 22  103.861500
# 23  103.907395
# 24   -2.226237
# 25  -71.209221
# 26   58.098658
# 27  103.843492
# 28 -121.933831
# 29  -65.213986
# 30  103.954360
# 31  103.887821
# 32 -120.571872
# 33  103.907331
# 34  168.660810
# 35  -95.782241
# 36  103.852612
# 37  103.877379
# 38  112.251427
# 39  103.895175
# 40  103.874462
# 41  107.537700
# 42  103.845154
# 43  103.863280
# 44  103.852603
# 45  103.753311
# 46  103.943571
# 47  103.815280
# 48  132.016667
# 49  103.849741
# 50  103.648236
# 51  -80.343282
# 52  103.681031
# 53 -115.225268

# %% [markdown]
# Correcting the incorrect coordinates in the table,the correct locations are obtained from Google search

# %%
#Replacing erroneous coordinates with the correct ones
raw_table.iloc[5,4]=1.2819 #Bukit Merah
raw_table.iloc[5,5]=103.8239
raw_table.iloc[8,4]=1.36666667 #CentralWater Catchment
raw_table.iloc[8,5]=103.80000000
raw_table.iloc[9,4]=1.3450 #Changi
raw_table.iloc[9,5]=103.9832
raw_table.iloc[13,4]=1.2867 #Downtown Core
raw_table.iloc[13,5]=103.8535
raw_table.iloc[20,4]=1.4260 #Mandai
raw_table.iloc[20,5]=103.8241
raw_table.iloc[24,4]=1.2858 #Museum
raw_table.iloc[24,5]=103.8507
raw_table.iloc[25,4]=1.3076 #Newton
raw_table.iloc[25,5]=103.8404
raw_table.iloc[26,4]=1.4064 #North-Eastern Islands
raw_table.iloc[26,5]=104.0323
raw_table.iloc[28,4]=1.3048 #Orchard
raw_table.iloc[28,5]=103.8318
raw_table.iloc[29,4]=1.2849 #Outram
raw_table.iloc[29,5]=103.8439
raw_table.iloc[32,4]=1.3376 #Pioneer
raw_table.iloc[32,5]=103.6974
raw_table.iloc[34,4]=1.2942 #Queenstown
raw_table.iloc[34,5]=103.7861
raw_table.iloc[35,4]=1.2895 #River Valley
raw_table.iloc[35,5]=103.8258
raw_table.iloc[41,4]=1.4443 #Simpang
raw_table.iloc[41,5]=103.8428
raw_table.iloc[48,4]=1.3555 #Tengah
raw_table.iloc[48,5]=103.7308
raw_table.iloc[51,4]=1.2479 #Western Islands
raw_table.iloc[51,5]=103.6768
raw_table.iloc[53,4]=1.4304 #Woodlands
raw_table.iloc[53,5]=103.8354

raw_table.head(54)
# Out:
#                   Area_Name      Region   Area Population  Area_lat  \
# 0                Ang Mo Kio  North-East  13.94    165,710  1.369842
# 1                     Bedok        East  21.69    281,300  1.323976
# 2                    Bishan     Central   7.62     88,490  1.351452
# 3                  Boon Lay        West   8.23         30  1.345640
# 4               Bukit Batok        West  11.13    144,410  1.349057
# 5               Bukit Merah     Central  14.34    151,870  1.281900
# 6             Bukit Panjang        West   8.99    140,820  1.377921
# 7               Bukit Timah     Central  17.53     77,280  1.354690
# 8   Central Water Catchment       North  37.15          *  1.366667
# 9                    Changi        East  40.61      2,080  1.345000
# 10               Changi Bay        East    1.7          *  1.316850
# 11            Choa Chu Kang        West   6.11    187,510  1.389260
# 12                 Clementi        West   9.49     93,000  1.314026
# 13            Downtown Core     Central   4.34      2,510  1.286700
# 14                  Geylang     Central   9.64    111,610  1.318186
# 15                  Hougang  North-East  13.93    223,010  1.373360
# 16              Jurong East        West  17.83     81,180  1.333115
# 17              Jurong West        West  14.69    266,720  1.339636
# 18                  Kallang     Central   9.17    101,420  1.310759
# 19             Lim Chu Kang       North   17.3        110  1.434217
# 20                   Mandai       North  11.77      2,090  1.426000
# 21              Marina East     Central   1.82          *  1.288624
# 22             Marina South     Central   1.62          *  1.276998
# 23            Marine Parade     Central   6.12     47,250  1.302689
# 24                   Museum     Central   0.83        420  1.285800
# 25                   Newton     Central   2.07      7,640  1.307600
# 26    North-Eastern Islands  North-East  42.88         50  1.406400
# 27                   Novena     Central   8.98     48,950  1.320084
# 28                  Orchard     Central   0.96        990  1.304800
# 29                   Outram     Central   1.37     20,030  1.284900
# 30                Pasir Ris        East  15.02    146,920  1.375989
# 31               Paya Lebar        East  11.69         40  1.353899
# 32                  Pioneer        West   12.1         90  1.337600
# 33                  Punggol  North-East   9.34    161,570  1.398033
# 34               Queenstown     Central  20.43     97,870  1.294200
# 35             River Valley     Central   1.48      9,930  1.289500
# 36                   Rochor     Central   1.62     13,450  1.303984
# 37                  Seletar  North-East  10.25        250  1.409849
# 38                Sembawang       North  12.34     87,380  1.126417
# 39                 Sengkang  North-East  10.59    240,640  1.390949
# 40                Serangoon  North-East   10.1    117,310  1.363236
# 41                  Simpang       North   5.13          *  1.444300
# 42          Singapore River     Central   0.96      2,980  1.289178
# 43         Southern Islands     Central   6.07      1,800  1.271089
# 44             Straits View     Central   0.77          *  1.278333
# 45             Sungei Kadut       North  15.99        780  1.414997
# 46                 Tampines        East  20.89    257,110  1.354653
# 47                  Tanglin     Central   7.63     20,960  1.306044
# 48                   Tengah        West    7.4         10  1.355500
# 49                Toa Payoh     Central   8.17    120,480  1.335391
# 50                     Tuas        West  30.04         70  1.329372
# 51          Western Islands        West  39.47         10  1.247900
# 52  Western Water Catchment        West  69.46        720  1.366452
# 53                Woodlands       North  13.59    252,530  1.430400
#
#       Area_lon
# 0   103.846609
# 1   103.930216
# 2   103.848250
# 3   103.711802
# 4   103.749591
# 5   103.823900
# 6   103.771866
# 7   103.776372
# 8   103.800000
# 9   103.983200
# 10  104.020649
# 11  103.743728
# 12  103.762410
# 13  103.853500
# 14  103.887056
# 15  103.886091
# 16  103.742297
# 17  103.707339
# 18  103.866262
# 19  103.714987
# 20  103.824100
# 21  103.869827
# 22  103.861500
# 23  103.907395
# 24  103.850700
# 25  103.840400
# 26  104.032300
# 27  103.843492
# 28  103.831800
# 29  103.843900
# 30  103.954360
# 31  103.887821
# 32  103.697400
# 33  103.907331
# 34  103.786100
# 35  103.825800
# 36  103.852612
# 37  103.877379
# 38  112.251427
# 39  103.895175
# 40  103.874462
# 41  103.842800
# 42  103.845154
# 43  103.863280
# 44  103.852603
# 45  103.753311
# 46  103.943571
# 47  103.815280
# 48  103.730800
# 49  103.849741
# 50  103.648236
# 51  103.676800
# 52  103.681031
# 53  103.835400

# %% [markdown]
# Sorting the table in descending order of the population

# %%
raw_table['Population']=raw_table['Population'].str.replace(",","")
raw_table['Population']=raw_table['Population'].str.replace("*","")
initial_table=raw_table[raw_table.Population!=""]
initial_table['Population']=initial_table['Population'].astype(float)
initial_table.sort_values(by='Population', ascending=False)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Area_Name      Region   Area  Population  Area_lat  \
# 1                     Bedok        East  21.69    281300.0  1.323976
# 17              Jurong West        West  14.69    266720.0  1.339636
# 46                 Tampines        East  20.89    257110.0  1.354653
# 53                Woodlands       North  13.59    252530.0  1.430400
# 39                 Sengkang  North-East  10.59    240640.0  1.390949
# 15                  Hougang  North-East  13.93    223010.0  1.373360
# 54                   Yishun       North  21.24    214940.0  1.428136
# 11            Choa Chu Kang        West   6.11    187510.0  1.389260
# 0                Ang Mo Kio  North-East  13.94    165710.0  1.369842
# 33                  Punggol  North-East   9.34    161570.0  1.398033
# 5               Bukit Merah     Central  14.34    151870.0  1.281900
# 30                Pasir Ris        East  15.02    146920.0  1.375989
# 4               Bukit Batok        West  11.13    144410.0  1.349057
# 6             Bukit Panjang        West   8.99    140820.0  1.377921
# 49                Toa Payoh     Central   8.17    120480.0  1.335391
# 40                Serangoon  North-East   10.1    117310.0  1.363236
# 14                  Geylang     Central   9.64    111610.0  1.318186
# 18                  Kallang     Central   9.17    101420.0  1.310759
# 34               Queenstown     Central  20.43     97870.0  1.294200
# 12                 Clementi        West   9.49     93000.0  1.314026
# 2                    Bishan     Central   7.62     88490.0  1.351452
# 38                Sembawang       North  12.34     87380.0  1.126417
# 16              Jurong East        West  17.83     81180.0  1.333115
# 7               Bukit Timah     Central  17.53     77280.0  1.354690
# 27                   Novena     Central   8.98     48950.0  1.320084
# 23            Marine Parade     Central   6.12     47250.0  1.302689
# 47                  Tanglin     Central   7.63     20960.0  1.306044
# 29                   Outram     Central   1.37     20030.0  1.284900
# 36                   Rochor     Central   1.62     13450.0  1.303984
# 35             River Valley     Central   1.48      9930.0  1.289500
# 25                   Newton     Central   2.07      7640.0  1.307600
# 42          Singapore River     Central   0.96      2980.0  1.289178
# 13            Downtown Core     Central   4.34      2510.0  1.286700
# 20                   Mandai       North  11.77      2090.0  1.426000
# 9                    Changi        East  40.61      2080.0  1.345000
# 43         Southern Islands     Central   6.07      1800.0  1.271089
# 28                  Orchard     Central   0.96       990.0  1.304800
# 45             Sungei Kadut       North  15.99       780.0  1.414997
# 52  Western Water Catchment        West  69.46       720.0  1.366452
# 24                   Museum     Central   0.83       420.0  1.285800
# 37                  Seletar  North-East  10.25       250.0  1.409849
# 19             Lim Chu Kang       North   17.3       110.0  1.434217
# 32                  Pioneer        West   12.1        90.0  1.337600
# 50                     Tuas        West  30.04        70.0  1.329372
# 26    North-Eastern Islands  North-East  42.88        50.0  1.406400
# 31               Paya Lebar        East  11.69        40.0  1.353899
# 3                  Boon Lay        West   8.23        30.0  1.345640
# 48                   Tengah        West    7.4        10.0  1.355500
# 51          Western Islands        West  39.47        10.0  1.247900
#
#       Area_lon
# 1   103.930216
# 17  103.707339
# 46  103.943571
# 53  103.835400
# 39  103.895175
# 15  103.886091
# 54  103.833694
# 11  103.743728
# 0   103.846609
# 33  103.907331
# 5   103.823900
# 30  103.954360
# 4   103.749591
# 6   103.771866
# 49  103.849741
# 40  103.874462
# 14  103.887056
# 18  103.866262
# 34  103.786100
# 12  103.762410
# 2   103.848250
# 38  112.251427
# 16  103.742297
# 7   103.776372
# 27  103.843492
# 23  103.907395
# 47  103.815280
# 29  103.843900
# 36  103.852612
# 35  103.825800
# 25  103.840400
# 42  103.845154
# 13  103.853500
# 20  103.824100
# 9   103.983200
# 43  103.863280
# 28  103.831800
# 45  103.753311
# 52  103.681031
# 24  103.850700
# 37  103.877379
# 19  103.714987
# 32  103.697400
# 50  103.648236
# 26  104.032300
# 31  103.887821
# 3   103.711802
# 48  103.730800
# 51  103.676800

# %% [markdown]
# Resetting the index and creating a new area table with only the 10 most populous areas

# %%
area_table=initial_table.sort_values(by='Population', ascending=False)
area_table=area_table.head(10)
area_table.reset_index(drop=True)
# Out:
#        Area_Name      Region   Area  Population  Area_lat    Area_lon
# 0          Bedok        East  21.69    281300.0  1.323976  103.930216
# 1    Jurong West        West  14.69    266720.0  1.339636  103.707339
# 2       Tampines        East  20.89    257110.0  1.354653  103.943571
# 3      Woodlands       North  13.59    252530.0  1.430400  103.835400
# 4       Sengkang  North-East  10.59    240640.0  1.390949  103.895175
# 5        Hougang  North-East  13.93    223010.0  1.373360  103.886091
# 6         Yishun       North  21.24    214940.0  1.428136  103.833694
# 7  Choa Chu Kang        West   6.11    187510.0  1.389260  103.743728
# 8     Ang Mo Kio  North-East  13.94    165710.0  1.369842  103.846609
# 9        Punggol  North-East   9.34    161570.0  1.398033  103.907331

# %% [markdown]
# Installing and importing Folium to view the location on the map

# %%
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# Displaying the locations on the map

# %%
# create map of Singapore using latitude and longitude values
latitude=1.3521
longitude=103.8198
map_SG = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, area, population in zip(area_table['Area_lat'], area_table['Area_lon'], area_table['Area_Name'], area_table['Population']):
    label = '{}, {}'.format(area, population)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_SG)  
    
map_SG
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Getting venue data from FourSquare API

# %%
VERSION = '20180605'
LIMIT=100
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Area', 
                  'Area Latitude', 
                  'Area Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)
SG_venues = getNearbyVenues(names=area_table['Area_Name'],
                            latitudes=area_table['Area_lat'],
                            longitudes=area_table['Area_lon'])
SG_venues.head(10)
# Out:
# Bedok
# Jurong West
# Tampines
# Woodlands
# Sengkang
# Hougang
# Yishun
# Choa Chu Kang
# Ang Mo Kio
# Punggol
#     Area  Area Latitude  Area Longitude                       Venue  \
# 0  Bedok       1.323976      103.930216       Bedok Chwee Kueh 勿洛水粿
# 1  Bedok       1.323976      103.930216        Ya Kun Kaya Toast 亞坤
# 2  Bedok       1.323976      103.930216                 Duke Bakery
# 3  Bedok       1.323976      103.930216            FairPrice Fínest
# 4  Bedok       1.323976      103.930216  Song Zhou Luo Bo Gao 松洲箩卜糕
# 5  Bedok       1.323976      103.930216                    5 Senses
# 6  Bedok       1.323976      103.930216            Dian Xiao Er 店小二
# 7  Bedok       1.323976      103.930216                    Greendot
# 8  Bedok       1.323976      103.930216            Din Tai Fung 鼎泰豐
# 9  Bedok       1.323976      103.930216              Hai Di Lao 海底捞
#
#    Venue Latitude  Venue Longitude                 Venue Category
# 0        1.324903       103.930250             Chinese Restaurant
# 1        1.324095       103.929198                    Coffee Shop
# 2        1.324691       103.932514                         Bakery
# 3        1.324140       103.929260                    Supermarket
# 4        1.324836       103.930520                 Breakfast Spot
# 5        1.324993       103.932517              French Restaurant
# 6        1.325118       103.930119             Chinese Restaurant
# 7        1.324506       103.930166  Vegetarian / Vegan Restaurant
# 8        1.324475       103.930164            Dumpling Restaurant
# 9        1.324152       103.929106              Hotpot Restaurant

# %% [markdown]
# Checking the most common venues in these 10 areas

# %%
SG_venues.shape
SG_venues.groupby(['Venue Category']).count().sort_values(by='Area', ascending=False)
# Out:
#                                Area  Area Latitude  Area Longitude  Venue  \
# Venue Category
# Food Court                       27             27              27     27
# Coffee Shop                      27             27              27     27
# Fast Food Restaurant             22             22              22     22
# Chinese Restaurant               21             21              21     21
# Japanese Restaurant              16             16              16     16
# Café                             15             15              15     15
# Asian Restaurant                 15             15              15     15
# Sandwich Place                   12             12              12     12
# Supermarket                      12             12              12     12
# Park                             10             10              10     10
# Bubble Tea Shop                  10             10              10     10
# Sushi Restaurant                 10             10              10     10
# Dessert Shop                     10             10              10     10
# Gym                               9              9               9      9
# Shopping Mall                     9              9               9      9
# Noodle House                      8              8               8      8
# Bakery                            8              8               8      8
# Indian Restaurant                 7              7               7      7
# Pharmacy                          6              6               6      6
# Bookstore                         5              5               5      5
# Italian Restaurant                5              5               5      5
# Seafood Restaurant                5              5               5      5
# Fried Chicken Joint               5              5               5      5
# Grocery Store                     4              4               4      4
# Multiplex                         4              4               4      4
# Burger Joint                      4              4               4      4
# Pool                              4              4               4      4
# Hainan Restaurant                 4              4               4      4
# Basketball Court                  3              3               3      3
# Vegetarian / Vegan Restaurant     3              3               3      3
# ...                             ...            ...             ...    ...
# Karaoke Bar                       1              1               1      1
# Mediterranean Restaurant          1              1               1      1
# Burrito Place                     1              1               1      1
# Taxi Stand                        1              1               1      1
# Bank                              1              1               1      1
# BBQ Joint                         1              1               1      1
# Thrift / Vintage Store            1              1               1      1
# Toy / Game Store                  1              1               1      1
# Athletics & Sports                1              1               1      1
# Shoe Store                        1              1               1      1
# Korean Restaurant                 1              1               1      1
# Sculpture Garden                  1              1               1      1
# Fruit & Vegetable Store           1              1               1      1
# Metro Station                     1              1               1      1
# High School                       1              1               1      1
# Gift Shop                         1              1               1      1
# Modern European Restaurant        1              1               1      1
# General Entertainment             1              1               1      1
# New American Restaurant           1              1               1      1
# Martial Arts Dojo                 1              1               1      1
# Hobby Shop                        1              1               1      1
# Diner                             1              1               1      1
# Pizza Place                       1              1               1      1
# French Restaurant                 1              1               1      1
# Plaza                             1              1               1      1
# Food Stand                        1              1               1      1
# Portuguese Restaurant             1              1               1      1
# Japanese Curry Restaurant         1              1               1      1
# Liquor Store                      1              1               1      1
# Food & Drink Shop                 1              1               1      1
#
#                                Venue Latitude  Venue Longitude
# Venue Category
# Food Court                                 27               27
# Coffee Shop                                27               27
# Fast Food Restaurant                       22               22
# Chinese Restaurant                         21               21
# Japanese Restaurant                        16               16
# Café                                       15               15
# Asian Restaurant                           15               15
# Sandwich Place                             12               12
# Supermarket                                12               12
# Park                                       10               10
# Bubble Tea Shop                            10               10
# Sushi Restaurant                           10               10
# Dessert Shop                               10               10
# Gym                                         9                9
# Shopping Mall                               9                9
# Noodle House                                8                8
# Bakery                                      8                8
# Indian Restaurant                           7                7
# Pharmacy                                    6                6
# Bookstore                                   5                5
# Italian Restaurant                          5                5
# Seafood Restaurant                          5                5
# Fried Chicken Joint                         5                5
# Grocery Store                               4                4
# Multiplex                                   4                4
# Burger Joint                                4                4
# Pool                                        4                4
# Hainan Restaurant                           4                4
# Basketball Court                            3                3
# Vegetarian / Vegan Restaurant               3                3
# ...                                       ...              ...
# Karaoke Bar                                 1                1
# Mediterranean Restaurant                    1                1
# Burrito Place                               1                1
# Taxi Stand                                  1                1
# Bank                                        1                1
# BBQ Joint                                   1                1
# Thrift / Vintage Store                      1                1
# Toy / Game Store                            1                1
# Athletics & Sports                          1                1
# Shoe Store                                  1                1
# Korean Restaurant                           1                1
# Sculpture Garden                            1                1
# Fruit & Vegetable Store                     1                1
# Metro Station                               1                1
# High School                                 1                1
# Gift Shop                                   1                1
# Modern European Restaurant                  1                1
# General Entertainment                       1                1
# New American Restaurant                     1                1
# Martial Arts Dojo                           1                1
# Hobby Shop                                  1                1
# Diner                                       1                1
# Pizza Place                                 1                1
# French Restaurant                           1                1
# Plaza                                       1                1
# Food Stand                                  1                1
# Portuguese Restaurant                       1                1
# Japanese Curry Restaurant                   1                1
# Liquor Store                                1                1
# Food & Drink Shop                           1                1
#
# [102 rows x 6 columns]

# %%
# one hot encoding
SG_onehot = pd.get_dummies(SG_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
SG_onehot['Area'] = SG_venues['Area'] 

# move neighborhood column to the first column
fixed_columns = [SG_onehot.columns[-1]] + list(SG_onehot.columns[:-1])
SG_onehot = SG_onehot[fixed_columns]

SG_onehot.head()

SG_grouped = SG_onehot.groupby('Area').mean().reset_index()
SG_grouped
# Out:
#             Area  Accessories Store  American Restaurant    Arcade  \
# 0     Ang Mo Kio           0.000000             0.000000  0.000000
# 1          Bedok           0.000000             0.017241  0.000000
# 2  Choa Chu Kang           0.000000             0.000000  0.000000
# 3        Hougang           0.000000             0.000000  0.000000
# 4    Jurong West           0.000000             0.016129  0.000000
# 5        Punggol           0.000000             0.000000  0.000000
# 6       Sengkang           0.000000             0.000000  0.000000
# 7       Tampines           0.000000             0.012195  0.000000
# 8      Woodlands           0.021277             0.000000  0.021277
# 9         Yishun           0.021277             0.000000  0.021277
#
#    Asian Restaurant  Athletics & Sports  BBQ Joint    Bakery      Bank  \
# 0          0.020408            0.000000   0.000000  0.020408  0.020408
# 1          0.034483            0.000000   0.000000  0.017241  0.000000
# 2          0.066667            0.000000   0.000000  0.000000  0.000000
# 3          0.038462            0.038462   0.000000  0.038462  0.000000
# 4          0.096774            0.000000   0.016129  0.000000  0.000000
# 5          0.000000            0.000000   0.000000  0.000000  0.000000
# 6          0.037037            0.000000   0.000000  0.037037  0.000000
# 7          0.036585            0.000000   0.000000  0.048780  0.000000
# 8          0.000000            0.000000   0.000000  0.000000  0.000000
# 9          0.000000            0.000000   0.000000  0.000000  0.000000
#
#    Basketball Court  ...  Supermarket  Sushi Restaurant  Taxi Stand  Tea Room  \
# 0          0.000000  ...     0.040816          0.020408    0.000000  0.000000
# 1          0.000000  ...     0.034483          0.034483    0.000000  0.000000
# 2          0.000000  ...     0.000000          0.000000    0.000000  0.000000
# 3          0.000000  ...     0.000000          0.000000    0.000000  0.000000
# 4          0.000000  ...     0.016129          0.016129    0.000000  0.000000
# 5          0.000000  ...     0.000000          0.000000    0.000000  0.000000
# 6          0.037037  ...     0.037037          0.037037    0.000000  0.000000
# 7          0.012195  ...     0.024390          0.036585    0.012195  0.000000
# 8          0.021277  ...     0.042553          0.021277    0.000000  0.021277
# 9          0.000000  ...     0.042553          0.021277    0.000000  0.021277
#
#    Thai Restaurant  Thrift / Vintage Store  Toy / Game Store  \
# 0         0.000000                0.000000          0.000000
# 1         0.000000                0.017241          0.000000
# 2         0.066667                0.000000          0.000000
# 3         0.000000                0.000000          0.000000
# 4         0.000000                0.000000          0.000000
# 5         0.000000                0.000000          0.000000
# 6         0.000000                0.000000          0.000000
# 7         0.024390                0.000000          0.012195
# 8         0.000000                0.000000          0.000000
# 9         0.000000                0.000000          0.000000
#
#    Vegetarian / Vegan Restaurant  Video Game Store  Wings Joint
# 0                       0.020408          0.000000     0.000000
# 1                       0.017241          0.000000     0.017241
# 2                       0.000000          0.000000     0.000000
# 3                       0.038462          0.000000     0.000000
# 4                       0.000000          0.000000     0.016129
# 5                       0.000000          0.000000     0.000000
# 6                       0.000000          0.037037     0.000000
# 7                       0.000000          0.000000     0.000000
# 8                       0.000000          0.021277     0.000000
# 9                       0.000000          0.021277     0.000000
#
# [10 rows x 103 columns]

# %% [markdown]
# Finding the 5 most common venues in all the 10 areas

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
SG_venues_sorted = pd.DataFrame(columns=columns)
SG_venues_sorted['Area'] = SG_grouped['Area']

for ind in np.arange(SG_grouped.shape[0]):
    SG_venues_sorted.iloc[ind, 1:] = return_most_common_venues(SG_grouped.iloc[ind, :], num_top_venues)

SG_venues_sorted.head(10)
# Out:
#             Area 1st Most Common Venue 2nd Most Common Venue  \
# 0     Ang Mo Kio            Food Court           Coffee Shop
# 1          Bedok           Coffee Shop    Chinese Restaurant
# 2  Choa Chu Kang  Fast Food Restaurant                  Park
# 3        Hougang            Food Court           Coffee Shop
# 4    Jurong West   Japanese Restaurant      Asian Restaurant
# 5        Punggol           High School    Chinese Restaurant
# 6       Sengkang           Coffee Shop  Fast Food Restaurant
# 7       Tampines           Coffee Shop                Bakery
# 8      Woodlands    Chinese Restaurant                  Park
# 9         Yishun            Food Court    Chinese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 0       Bubble Tea Shop        Sandwich Place  Fast Food Restaurant
# 1        Sandwich Place            Food Court   Japanese Restaurant
# 2            Food Court              Pharmacy           Coffee Shop
# 3          Noodle House               Stadium                  Café
# 4  Fast Food Restaurant                  Café    Chinese Restaurant
# 5                Casino           Bus Station            Playground
# 6            Food Court         Shopping Mall                  Café
# 7   Japanese Restaurant                  Café         Shopping Mall
# 8            Food Court          Noodle House           Coffee Shop
# 9           Coffee Shop           Supermarket          Noodle House
